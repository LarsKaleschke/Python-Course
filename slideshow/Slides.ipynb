# %% [markdown]
# # Jupyter slides
#
# ## Why?
#
#  * Notebook: one file including code and documentation
#  * Different representations can be derived from notebook, e.g.
#   * ascii, latex, markdown, pdf, html
#   * slides (html)
#  * No powerpoint needed, just a browser
#
# ## Overview
#
#  * How to generate and present Jupyter notebook slides
#  * Slides, sub-slides, and fragments
#  * Reveal.js framework
#  * Static and interactive slideshows
# ---
#
# Lars Kaleschke, January 2016/2017

# %% [markdown]
# Speaker notes. Don't forget to say this! But perhaps not yet supported?

# %% [markdown]
# # Notebook slides
#
# Generating slides from notebooks is easy:
#
#  * Select view -> cell toolbar -> slideshow
#  * Convert notebook to html slides
#  * View with browser or upload slides on remote server (e.g. Github)

# %% [markdown]
# ## This is a Sub-Slide with Fragments

# %%
# !jupyter-nbconvert Slides.ipynb --to slides --reveal-prefix=reveal.js
# Out:
# [NbConvertApp] Converting notebook Slides.ipynb to slides
# [NbConvertApp] Writing 317067 bytes to Slides.slides.html

# %% [markdown]
# Save the notebook and execute the cell above: Jupyter converts the notebook to html-slides.

# %% [markdown]
# # Notebook slide tutorial
#
#  * Create empty directory
#  * Download reveal.js framework
#  * Create Jupyter notebook slides
#  * Convert to notebook to html-slides
#  * Copy to local machine and open with browser

# %% [markdown]
# # Reveal.js
#
# Reveal.js is a framework for easily creating beautiful presentations using HTML.
#
# Download zip file and extract or

# %%
# !git clone https://github.com/hakimel/reveal.js.git
# Out:
# Cloning into reveal.js...
# remote: Counting objects: 9526, done.
# remote: Total 9526 (delta 0), reused 0 (delta 0), pack-reused 9526
# Receiving objects: 100% (9526/9526), 7.13 MiB | 3.61 MiB/s, done.
# Resolving deltas: 100% (5205/5205), done.

# %% [markdown]
# # Example slide with python code

# %%
# %pylab inline
N = 50
r = 2 * random.rand(N)
theta = 2 * pi * random.rand(N)
area = 200 * r**2
ax=plt.subplot(111, projection='polar')
c=ax.scatter(theta, r, c=theta, s=area, cmap=plt.cm.hsv, alpha=0.5)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Types of slideshows
#
# There are at least two different types of presentations
#
#  * static (html)
#  * interactive
#
# Here we have used the static html version.
#
# An interactive slideshow allows to change the content on the fly. For this you have to use the [RISE extension](https://github.com/damianavila/RISE) or wait for future Jupyter versions.
#
# ## nbpresent
#
# https://github.com/Anaconda-Platform/nbpresent

# %% [markdown]
# # Thank you for your attention
